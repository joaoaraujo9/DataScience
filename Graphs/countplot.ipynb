# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
from plotly.offline import init_notebook_mode

# %%
data = pd.read_csv('C:/Users/joao_/Desktop/4 ANO JOAO/SINO/VS CODE PROJETO/Datasets/bank-full-transformed.csv')

# %%
variaveis = ["education","housing","default","loan","month","age","previous", "pdays","balance", "campaign"]
for i in variaveis:

    sns.countplot(x=i, hue=data['y'], data=data)
    plt.show()
